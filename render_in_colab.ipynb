# %% [markdown]
# # Gemini 3.5 Pro Delay B-Roll - 1-Click Google Colab Cloud Renderer
#
# Run this notebook in Google Colab to render the Remotion video at high speed on Google Cloud CPUs/GPUs for free.
#
# ### Instructions:
# 1. In the menu above, click **Runtime -> Run all** (or press `Ctrl+F9`).
# 2. Wait for the render to finish (~3 to 5 minutes).
# 3. The final `gemini_35_pro_delay.mp4` video will automatically download to your computer!

# %%
# Step 1: Clone repository and install FFmpeg + Node dependencies
# !git clone https://github.com/atiqur5132-cmd/automatic-broll.git
# !apt-get update && apt-get install -y ffmpeg
# !cd automatic-broll && npm install

# %%
# Step 2: Render the Remotion video with high concurrency on cloud CPU/GPU
# !cd automatic-broll && npx remotion render MyVideo out/gemini_35_pro_delay.mp4 --concurrency=4

# %%
# Step 3: Automatically download the rendered MP4 file to your computer
from google.colab import files
files.download('automatic-broll/out/gemini_35_pro_delay.mp4')
