# %% [markdown]
# # Gemini 3.5 Pro Delay B-Roll - 1-Click Google Colab Cloud Renderer
#
# Run this notebook in Google Colab to render the Remotion video at high speed on Google Cloud CPUs/GPUs for free.
#
# ### Note:
# If your GitHub repository is **Private**, make sure to either make it Public or upload your project files directly to Colab.

# %%
import os

# Step 1: Clone repository (or pull latest if already exists)
if not os.path.exists('automatic-broll'):
    # !git clone https://github.com/atiqur5132-cmd/automatic-broll.git
else:
    # !cd automatic-broll && git pull

# Step 2: Install system FFmpeg and Node packages
# !apt-get update && apt-get install -y ffmpeg
# !cd automatic-broll && npm install

# Step 3: Render video
# !cd automatic-broll && npx remotion render MyVideo out/gemini_35_pro_delay.mp4 --concurrency=4

# Step 4: Download video safely
video_path = 'automatic-broll/out/gemini_35_pro_delay.mp4'
if os.path.exists(video_path):
    from google.colab import files
    files.download(video_path)
else:
    print('ERROR: Video file was not generated. Please check the logs above.')
